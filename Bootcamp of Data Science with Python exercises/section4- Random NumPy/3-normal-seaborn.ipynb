# %% [markdown]
# # Generate a standard normal distribution and use
# # the Seaborn module to build a visualization of the data. The sample must
# # contain 3000 numbers. Use the Seaborn module's distplot() function and also import.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = np.random.normal(size=3000)
sns.displot(data, kind="kde")
plt.show()

# %%
sns.displot(data, kind="hist")
plt.show()
