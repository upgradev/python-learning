# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_data = np.arange(9)

# %%
plt.plot(new_data)
plt.title("The new data graph")
plt.xlabel("x label name")
plt.ylabel("x label name")
# Out:
# Text(0, 0.5, 'x label name')

# %%
plt.title("The new data graph")
# Out:
# Text(0.5, 1.0, 'The new data graph')

# %%
plt.xlabel("x label name")
# Out:
# Text(0.5, 0, 'x label name')

# %%
plt.ylabel("y label name")
# Out:
# Text(0, 0.5, 'y label name')

# %%
x = [1,2,3,4,5,6,7]
y = [1,4,9,16,25,36,49]

# %%
plt.plot(x, y)
