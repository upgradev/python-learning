# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set()

# %%
new_iris = sns.load_dataset('iris')

# %%
new_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
new_iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
new_iris.petal_length.plot()
# Out:
# <AxesSubplot:>

# %%
new_iris.plot()
# Out:
# <AxesSubplot:>

# %%
new_d = pd.Series(np.random.rand(7), index=list('ABCDEFG'))

# %%
new_d
# Out:
# A    0.073470
# B    0.299995
# C    0.708402
# D    0.803789
# E    0.650652
# F    0.472486
# G    0.230227
# dtype: float64

# %%
new_d.plot.bar(color="r", alpha=1) #color and transparent
# Out:
# <AxesSubplot:>

# %%
new_d.plot.barh(color="y", alpha=1) #color and transparent
# Out:
# <AxesSubplot:>

# %%
new_loading = sns.load_dataset('tips')

# %%
new_loading.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
size_of_day = pd.crosstab(new_loading["day"], new_loading["size"])

# %%
size_of_day
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
size_of_day.plot.barh()
# Out:
# <AxesSubplot:ylabel='day'>

# %%
size_of_day.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
size_of_day.plot.bar()
# Out:
# <AxesSubplot:xlabel='day'>
